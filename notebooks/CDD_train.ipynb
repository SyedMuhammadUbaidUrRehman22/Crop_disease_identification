# %%
# !pip install torch torchvision numpy pillow matplotlib pandas scikit-learn tqdm jupyter
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 79.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 102.5 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/CDD_upload
# Out:
# /content/drive/MyDrive/CDD_upload

# %%
# !python models/train.py --model mobilenetv2 --epochs 10 --batch_size 16 --lr 0.0001 --dropout 0.3
# Out:
# Using device: cuda
# Creating datasets...
# Creating dataloaders...
# Number of classes: 16
# Training samples: 1866
# Validation samples: 401
# Test samples: 427
# Class mapping saved to: /content/drive/MyDrive/CDD_upload/outputs/logs/mobilenetv2/class_mapping.csv
# Creating model: mobilenetv2
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
# 100% 13.6M/13.6M [00:00<00:00, 144MB/s]
# Using inverse-frequency class weights.
#
# Starting training...
#
# Epoch 1/10
# ----------------------------------------
# Train Loss: 2.0523 | Train Acc: 0.3242
# Val Loss:   1.4808 | Val Acc:   0.4838
# Saved best model to: /content/drive/MyDrive/CDD_upload/outputs/weights/mobilenetv2/best.pth
#
# Epoch 2/10
# ----------------------------------------
# Train Loss: 1.3485 | Train Acc: 0.5397
# Val Loss:   1.1553 | Val Acc:   0.5860
# ...

# %%
# !python models/evaluate.py --model mobilenetv2 --checkpoint outputs/weights/mobilenetv2/best.pth --batch_size 16
# Out:
# Using device: cuda
# Creating datasets...
# Creating dataloaders...
# Checkpoint model: mobilenetv2
# Number of classes: 16
# Running inference on test set...
#
# Evaluation Metrics
# ------------------------------
# accuracy: 0.7260
# precision: 0.7410
# recall: 0.7260
# f1_score: 0.7257
# auc_roc: 0.9666
# Metrics saved to: /content/drive/MyDrive/CDD_upload/outputs/logs/mobilenetv2/test_metrics.csv
#
# Classification Report
# --------------------------------------------------
#                             precision    recall  f1-score   support
#
#         apple_leaf_healthy       0.83      0.95      0.88        20
#            apple_leaf_rust       0.86      0.79      0.82        38
#            apple_leaf_scab       0.77      0.68      0.72        34
#        corn_grey_leaf_spot       0.63      0.86      0.73        22
#           corn_leaf_blight       0.88      0.70      0.78        43
#          corn_leaf_healthy       0.67      0.83      0.74        12
# ...

# %%
# !python models/train.py --model resnet18 --epochs 10 --batch_size 16 --lr 0.0001 --dropout 0.3
# Out:
# Using device: cuda
# Creating datasets...
# Creating dataloaders...
# Number of classes: 16
# Training samples: 1866
# Validation samples: 401
# Test samples: 427
# Class mapping saved to: /content/drive/MyDrive/CDD_upload/outputs/logs/resnet18/class_mapping.csv
# Creating model: resnet18
# Using inverse-frequency class weights.
#
# Starting training...
#
# Epoch 1/10
# ----------------------------------------
# Train Loss: 2.0596 | Train Acc: 0.3183
# Val Loss:   1.4582 | Val Acc:   0.4988
# Saved best model to: /content/drive/MyDrive/CDD_upload/outputs/weights/resnet18/best.pth
#
# Epoch 2/10
# ----------------------------------------
# Train Loss: 1.3369 | Train Acc: 0.5348
# Val Loss:   1.3596 | Val Acc:   0.5212
# Saved best model to: /content/drive/MyDrive/CDD_upload/outputs/weights/resnet18/best.pth
#
# Epoch 3/10
# ----------------------------------------
# Train Loss: 1.1060 | Train Acc: 0.6184
# Val Loss:   1.1938 | Val Acc:   0.5761
# ...

# %%
# !python models/evaluate.py --model resnet18 --checkpoint outputs/weights/resnet18/best.pth --batch_size 16
# Out:
# Using device: cuda
# Creating datasets...
# Creating dataloaders...
# Checkpoint model: resnet18
# Number of classes: 16
# Running inference on test set...
#
# Evaluation Metrics
# ------------------------------
# accuracy: 0.6956
# precision: 0.7120
# recall: 0.6956
# f1_score: 0.6931
# auc_roc: 0.9624
# Metrics saved to: /content/drive/MyDrive/CDD_upload/outputs/logs/resnet18/test_metrics.csv
#
# Classification Report
# --------------------------------------------------
#                             precision    recall  f1-score   support
#
#         apple_leaf_healthy       0.77      1.00      0.87        20
#            apple_leaf_rust       0.78      0.74      0.76        38
#            apple_leaf_scab       0.63      0.71      0.67        34
#        corn_grey_leaf_spot       0.62      0.82      0.71        22
#           corn_leaf_blight       0.92      0.56      0.70        43
#          corn_leaf_healthy       0.50      0.83      0.62        12
# ...

# %%
# !python models/train.py --model efficientnet_b0 --epochs 10 --batch_size 8 --lr 0.0001 --dropout 0.3
# Out:
# Using device: cuda
# Creating datasets...
# Creating dataloaders...
# Number of classes: 16
# Training samples: 1866
# Validation samples: 401
# Test samples: 427
# Class mapping saved to: /content/drive/MyDrive/CDD_upload/outputs/logs/efficientnet_b0/class_mapping.csv
# Creating model: efficientnet_b0
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100% 20.5M/20.5M [00:00<00:00, 113MB/s]
# Using inverse-frequency class weights.
#
# Starting training...
#
# Epoch 1/10
# ----------------------------------------
# Train Loss: 2.4005 | Train Acc: 0.2605
# Val Loss:   1.7532 | Val Acc:   0.4190
# Saved best model to: /content/drive/MyDrive/CDD_upload/outputs/weights/efficientnet_b0/best.pth
#
# Epoch 2/10
# ----------------------------------------
# Train Loss: 1.6799 | Train Acc: 0.4609
# Val Loss:   1.4574 | Val Acc:   0.5262
# ...

# %%
# !python models/evaluate.py --model efficientnet_b0 --checkpoint outputs/weights/efficientnet_b0/best.pth --batch_size 8
# Out:
# Using device: cuda
# Creating datasets...
# Creating dataloaders...
# Checkpoint model: efficientnet_b0
# Number of classes: 16
# Running inference on test set...
#
# Evaluation Metrics
# ------------------------------
# accuracy: 0.7190
# precision: 0.7320
# recall: 0.7190
# f1_score: 0.7172
# auc_roc: 0.9635
# Metrics saved to: /content/drive/MyDrive/CDD_upload/outputs/logs/efficientnet_b0/test_metrics.csv
#
# Classification Report
# --------------------------------------------------
#                             precision    recall  f1-score   support
#
#         apple_leaf_healthy       0.79      0.95      0.86        20
#            apple_leaf_rust       0.81      0.76      0.78        38
#            apple_leaf_scab       0.76      0.74      0.75        34
#        corn_grey_leaf_spot       0.52      0.55      0.53        22
#           corn_leaf_blight       0.78      0.67      0.72        43
#          corn_leaf_healthy       0.50      1.00      0.67        12
# ...

# %%
# !python models/train.py --model resnet50 --epochs 10 --batch_size 16 --lr 0.0001 --dropout 0.3
# Out:
# Using device: cuda
# Creating datasets...
# Creating dataloaders...
# Number of classes: 16
# Training samples: 1866
# Validation samples: 401
# Test samples: 427
# Class mapping saved to: /content/drive/MyDrive/CDD_upload/outputs/logs/resnet50/class_mapping.csv
# Creating model: resnet50
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100% 97.8M/97.8M [00:00<00:00, 124MB/s]
# Using inverse-frequency class weights.
#
# Starting training...
#
# Epoch 1/10
# ----------------------------------------
# Train Loss: 1.8866 | Train Acc: 0.3848
# Val Loss:   1.3106 | Val Acc:   0.5636
# Saved best model to: /content/drive/MyDrive/CDD_upload/outputs/weights/resnet50/best.pth
#
# Epoch 2/10
# ----------------------------------------
# Train Loss: 1.2428 | Train Acc: 0.5707
# Val Loss:   1.1765 | Val Acc:   0.5885
# Saved best model to: /content/drive/MyDrive/CDD_upload/outputs/weights/resnet50/best.pth
#
# ...

# %%
# !python models/evaluate.py --model resnet50 --checkpoint outputs/weights/resnet50/best.pth --batch_size 16
# Out:
# Using device: cuda
# Creating datasets...
# Creating dataloaders...
# Checkpoint model: resnet50
# Number of classes: 16
# Running inference on test set...
#
# Evaluation Metrics
# ------------------------------
# accuracy: 0.7213
# precision: 0.7381
# recall: 0.7213
# f1_score: 0.7207
# auc_roc: 0.9661
# Metrics saved to: /content/drive/MyDrive/CDD_upload/outputs/logs/resnet50/test_metrics.csv
#
# Classification Report
# --------------------------------------------------
#                             precision    recall  f1-score   support
#
#         apple_leaf_healthy       0.91      1.00      0.95        20
#            apple_leaf_rust       0.86      0.79      0.82        38
#            apple_leaf_scab       0.79      0.88      0.83        34
#        corn_grey_leaf_spot       0.58      0.68      0.62        22
#           corn_leaf_blight       0.93      0.65      0.77        43
#          corn_leaf_healthy       0.71      0.83      0.77        12
# ...

# %%
# !python models/train.py --model densenet201 --epochs 10 --batch_size 8 --lr 0.0001 --dropout 0.3
# Out:
# Using device: cuda
# Creating datasets...
# Creating dataloaders...
# Number of classes: 16
# Training samples: 1866
# Validation samples: 401
# Test samples: 427
# Class mapping saved to: /content/drive/MyDrive/CDD_upload/outputs/logs/densenet201/class_mapping.csv
# Creating model: densenet201
# Downloading: "https://download.pytorch.org/models/densenet201-c1103571.pth" to /root/.cache/torch/hub/checkpoints/densenet201-c1103571.pth
# 100% 77.4M/77.4M [00:00<00:00, 166MB/s]
# Using inverse-frequency class weights.
#
# Starting training...
#
# Epoch 1/10
# ----------------------------------------
# Train Loss: 1.9548 | Train Acc: 0.3628
# Val Loss:   1.3710 | Val Acc:   0.5187
# Saved best model to: /content/drive/MyDrive/CDD_upload/outputs/weights/densenet201/best.pth
#
# Epoch 2/10
# ----------------------------------------
# Train Loss: 1.3168 | Train Acc: 0.5772
# Val Loss:   1.1364 | Val Acc:   0.6234
# ...

# %%
# !python models/evaluate.py --model densenet201 --checkpoint outputs/weights/densenet201/best.pth --batch_size 8
# Out:
# Using device: cuda
# Creating datasets...
# Creating dataloaders...
# Checkpoint model: densenet201
# Number of classes: 16
# Running inference on test set...
#
# Evaluation Metrics
# ------------------------------
# accuracy: 0.7377
# precision: 0.7491
# recall: 0.7377
# f1_score: 0.7360
# auc_roc: 0.9678
# Metrics saved to: /content/drive/MyDrive/CDD_upload/outputs/logs/densenet201/test_metrics.csv
#
# Classification Report
# --------------------------------------------------
#                             precision    recall  f1-score   support
#
#         apple_leaf_healthy       0.73      0.95      0.83        20
#            apple_leaf_rust       0.84      0.84      0.84        38
#            apple_leaf_scab       0.79      0.68      0.73        34
#        corn_grey_leaf_spot       0.53      0.82      0.64        22
#           corn_leaf_blight       0.77      0.63      0.69        43
#          corn_leaf_healthy       0.58      0.92      0.71        12
# ...

# %%
# !python models/train.py --model efficientnet_b3 --epochs 10 --batch_size 8 --lr 0.0001 --dropout 0.3
# Out:
# Using device: cuda
# Creating datasets...
# Creating dataloaders...
# Number of classes: 16
# Training samples: 1866
# Validation samples: 401
# Test samples: 427
# Class mapping saved to: /content/drive/MyDrive/CDD_upload/outputs/logs/efficientnet_b3/class_mapping.csv
# Creating model: efficientnet_b3
# Downloading: "https://download.pytorch.org/models/efficientnet_b3_rwightman-b3899882.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b3_rwightman-b3899882.pth
# 100% 47.2M/47.2M [00:00<00:00, 113MB/s]
# Using inverse-frequency class weights.
#
# Starting training...
#
# Epoch 1/10
# ----------------------------------------
# Train Loss: 2.4532 | Train Acc: 0.2572
# Val Loss:   2.0044 | Val Acc:   0.4264
# Saved best model to: /content/drive/MyDrive/CDD_upload/outputs/weights/efficientnet_b3/best.pth
#
# Epoch 2/10
# ----------------------------------------
# Train Loss: 1.6653 | Train Acc: 0.4796
# Val Loss:   1.5079 | Val Acc:   0.5162
# ...

# %%
# !python models/evaluate.py --model efficientnet_b3 --checkpoint outputs/weights/efficientnet_b3/best.pth --batch_size 8
# Out:
# Using device: cuda
# Creating datasets...
# Creating dataloaders...
# Checkpoint model: efficientnet_b3
# Number of classes: 16
# Running inference on test set...
#
# Evaluation Metrics
# ------------------------------
# accuracy: 0.7073
# precision: 0.7092
# recall: 0.7073
# f1_score: 0.7019
# auc_roc: 0.9682
# Metrics saved to: /content/drive/MyDrive/CDD_upload/outputs/logs/efficientnet_b3/test_metrics.csv
#
# Classification Report
# --------------------------------------------------
#                             precision    recall  f1-score   support
#
#         apple_leaf_healthy       0.78      0.90      0.84        20
#            apple_leaf_rust       0.76      0.82      0.78        38
#            apple_leaf_scab       0.74      0.68      0.71        34
#        corn_grey_leaf_spot       0.68      0.77      0.72        22
#           corn_leaf_blight       0.72      0.79      0.76        43
#          corn_leaf_healthy       0.86      1.00      0.92        12
# ...
